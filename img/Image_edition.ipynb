# %%
import cv2
from matplotlib import pyplot as plt
import numpy as np

# %%
# !ls
# Out:
# github_action_commit_file.png			 github_clone.png
# github_actions_highlight.png			 github_fork_highlight.png
# github_actions.png				 github_fork.png
# github_actions_python_application_highlight.png  Image_edition.ipynb
# github_actions_python_application.png

# %%
img = cv2.imread('github_action_commit_file.png')

# %%
img = cv2.rectangle(img,(1720,112),(1880,160),(0,0,255),3)
plt.imshow(img)
plt.show()

# %%
cv2.imwrite('github_action_commit_file.png', img)
# Out:
# True
